# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load and explore traditional e-commerce dataset
ecom_df = pd.read_csv(r'C:\Users\luket\Downloads\E-commerce churn dataset - REES46\rees46_customer_model.csv')
pd.set_option('display.max_columns', None)

print("E-commerce Dataset Shape:", ecom_df.shape)

for col in ecom_df.columns:
    dtype = ecom_df[col].dtype
    missing = ecom_df[col].isnull().sum()
    print(f"{col:40} {str(dtype):10} Missing: {missing}")
# Out:
# E-commerce Dataset Shape: (112610, 276)
# row_id                                   int64      Missing: 0
# user_id                                  int64      Missing: 0
# length_mean                              float64    Missing: 0
# start_year_mean                          float64    Missing: 0
# start_yearday_mean                       float64    Missing: 0
# start_month_mean                         float64    Missing: 0
# start_monthday_mean                      float64    Missing: 0
# start_week_mean                          float64    Missing: 0
# start_weekday_mean                       float64    Missing: 0
# start_isweekend_mean                     float64    Missing: 0
# start_hour_mean                          float64    Missing: 0
# haspurchase_mean                         float64    Missing: 0
# click_count_mean                         float64    Missing: 0
# view_count_mean                          float64    Missing: 0
# ...

# %%
# Load and explore Instagram platform e-commerce dataset
ig_df = pd.read_csv(r'C:\Users\luket\Downloads\platform commerce datasets\Instagram-datasets.csv')
pd.set_option('display.max_columns', None)

print("Instagram Dataset Shape:", ig_df.shape)

for col in ig_df.columns:
    dtype = ig_df[col].dtype
    missing = ig_df[col].isnull().sum()
    print(f"{col:40} {str(dtype):10} Missing: {missing}")
# Out:
# Instagram Dataset Shape: (1000, 14)
# url                                      object     Missing: 0
# comment_user                             object     Missing: 0
# comment_user_url                         object     Missing: 0
# comment_date                             object     Missing: 0
# comment                                  object     Missing: 0
# likes_number                             int64      Missing: 0
# replies_number                           int64      Missing: 0
# replies                                  object     Missing: 2
# hashtag_comment                          object     Missing: 994
# tagged_users_in_comment                  object     Missing: 854
# post_url                                 object     Missing: 0
# post_user                                object     Missing: 0
# comment_id                               int64      Missing: 0
# post_id                                  int64      Missing: 0

# %%
# Load and explore Tiktok platform e-commerce dataset
tt_df = pd.read_csv(r'C:\Users\luket\Downloads\platform commerce datasets\TikTok-datasets.csv')

print("Tiktok Dataset Shape:", tt_df.shape)

for col in tt_df.columns:
    dtype = tt_df[col].dtype
    missing = tt_df[col].isnull().sum()
    print(f"{col:40} {str(dtype):10} Missing: {missing}")
# Out:
# Tiktok Dataset Shape: (1000, 13)
# url                                      object     Missing: 0
# post_url                                 object     Missing: 0
# post_id                                  int64      Missing: 0
# post_date_created                        object     Missing: 0
# date_created                             object     Missing: 0
# comment_text                             object     Missing: 0
# num_likes                                int64      Missing: 0
# num_replies                              int64      Missing: 0
# commenter_user_name                      object     Missing: 0
# commenter_id                             int64      Missing: 0
# commenter_url                            object     Missing: 0
# comment_id                               int64      Missing: 0
# comment_url                              object     Missing: 0
